# %%
print("hello world")
# Out:
# hello world

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Siddharth\anaconda3\envs\dataeng\python.exe

# %%
# !where conda
# Out:
# C:\Users\Siddharth\anaconda3\condabin\conda.bat
# C:\Users\Siddharth\anaconda3\Library\bin\conda.bat
# C:\Users\Siddharth\anaconda3\Scripts\conda.exe

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
import pandas as pd

df = pd.read_csv("../data/combined_dataset.csv")

print(df.shape)
print(df.columns.tolist())
# Out:
# (1000, 24)
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']
